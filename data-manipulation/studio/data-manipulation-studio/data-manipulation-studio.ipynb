# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit the data set from our last studio. If you recall, California farmers were looking for advice on growing pumpkins. We will use the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# A **terminal market** is a central site, often in a metropolitan area, that serves as an assembly and trading place for commodities. Terminal markets for agricultural commodities are usually at or near major transportation hubs. [Definition Source](https://en.wikipedia.org/wiki/Terminal_market#:~:text=A%20terminal%20market%20is%20a,or%20near%20major%20transportation%20hubs)
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np

# Dataframe for Baltimore
baltimore_data = pd.read_csv("dataset/baltimore_9-24-2016_9-30-2017.csv")
baltimore_data
# Out:
#     Commodity Name  City Name  Type             Package      Variety  \
# 0         PUMPKINS  BALTIMORE   NaN        24 inch bins          NaN
# 1         PUMPKINS  BALTIMORE   NaN        24 inch bins          NaN
# 2         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 3         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 4         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# ..             ...        ...   ...                 ...          ...
# 148       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 149       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 150       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 151       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 152       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# 0           NaN    NaN  04/29/2017        270       280.0  ...     NaN
# 1           NaN    NaN  05/06/2017        270       280.0  ...     NaN
# 2           NaN    NaN  09/24/2016        160       160.0  ...     NaN
# 3           NaN    NaN  09/24/2016        160       160.0  ...     NaN
# 4           NaN    NaN  11/05/2016         90       100.0  ...     NaN
# ..          ...    ...         ...        ...         ...  ...     ...
# 148         NaN    NaN  09/30/2017         18        18.0  ...  ORANGE
# 149         NaN    NaN  09/30/2017         18        18.0  ...  ORANGE
# 150  ROUND TYPE    NaN  09/24/2016         15        15.0  ...     NaN
# 151  ROUND TYPE    NaN  10/01/2016         15        15.0  ...     NaN
# 152  ROUND TYPE    NaN  10/08/2016         15        15.0  ...     NaN
#
#      Environment Unit of Sale  Quality Condition Appearance  Storage Crop  \
# 0            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 1            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 2            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 3            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 4            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# ..           ...          ...      ...       ...        ...      ...  ...
# 148          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 149          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 150          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 151          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 152          NaN          NaN      NaN       NaN        NaN      NaN  NaN
#
#      Repack  Trans Mode
# 0         E         NaN
# 1         E         NaN
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# ..      ...         ...
# 148       N         NaN
# 149       N         NaN
# 150       N         NaN
# 151       N         NaN
# 152       N         NaN
#
# [153 rows x 25 columns]

# %%
# Dataframe for Boston
boston_data= pd.read_csv("dataset/boston_9-24-2016_9-30-2017.csv")
boston_data
# Out:
#     Commodity Name City Name  Type             Package      Variety  \
# 0         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 1         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 2         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 3         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 4         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# ..             ...       ...   ...                 ...          ...
# 347       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 348       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 349       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 350       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 351       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# 0           NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 1           NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 2           NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 3           NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 4           NaN    NaN  09/24/2016        160         180  ...  ORANGE
# ..          ...    ...         ...        ...         ...  ...     ...
# 347  ROUND TYPE    NaN  10/22/2016         15          18  ...  ORANGE
# 348  ROUND TYPE    NaN  10/29/2016         15          18  ...   WHITE
# 349  ROUND TYPE    NaN  10/29/2016         15          18  ...  ORANGE
# 350  ROUND TYPE    NaN  11/05/2016         15          18  ...   WHITE
# 351  ROUND TYPE    NaN  11/05/2016         15          18  ...  ORANGE
#
#      Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 1            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 2            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 3            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 4            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# ..           ...          ...     ...       ...        ...      ...  ...
# 347          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 348          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 349          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 350          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 351          NaN          NaN     NaN       NaN        NaN      NaN  NaN
#
#      Repack  Trans Mode
# 0         N         NaN
# 1         N         NaN
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# ..      ...         ...
# 347       N         NaN
# 348       N         NaN
# 349       N         NaN
# 350       N         NaN
# 351       N         NaN
#
# [352 rows x 25 columns]

# %%
# Dataframe for New York
newyork_data= pd.read_csv("dataset/new-york_9-24-2016_9-30-2017.csv")
newyork_data
# Out:
#     Commodity Name City Name  Type              Package      Variety  \
# 0         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 1         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 2         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 3         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 4         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# ..             ...       ...   ...                  ...          ...
# 107       PUMPKINS  NEW YORK   NaN       bushel cartons    MINIATURE
# 108       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 109       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 110       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 111       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0           NaN    NaN  09/24/2016        150         170  ...    NaN
# 1           NaN    NaN  09/24/2016        150         170  ...    NaN
# 2           NaN    NaN  09/24/2016        130         150  ...    NaN
# 3           NaN    NaN  09/24/2016        130         150  ...    NaN
# 4           NaN    NaN  09/24/2016        120         140  ...    NaN
# ..          ...    ...         ...        ...         ...  ...    ...
# 107         NaN    NaN  09/09/2017         32          32  ...    NaN
# 108  ROUND TYPE    NaN  10/08/2016         18          18  ...    NaN
# 109  ROUND TYPE    NaN  10/08/2016         18          18  ...    NaN
# 110  ROUND TYPE    NaN  10/15/2016         18          18  ...    NaN
# 111  ROUND TYPE    NaN  10/15/2016         18          18  ...    NaN
#
#      Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 1            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 2            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 3            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 4            NaN          NaN     NaN       NaN        NaN      NaN  NaN
# ..           ...          ...     ...       ...        ...      ...  ...
# 107          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 108          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 109          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 110          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 111          NaN          NaN     NaN       NaN        NaN      NaN  NaN
#
#      Repack  Trans Mode
# 0         N         NaN
# 1         N         NaN
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# ..      ...         ...
# 107       N         NaN
# 108       N         NaN
# 109       N         NaN
# 110       N         NaN
# 111       N         NaN
#
# [112 rows x 25 columns]

# %%
# Dataframe for Philadelphia
philadelphia_data= pd.read_csv("dataset/philadelphia_9-24-2016_9-30-2017.csv")
philadelphia_data
# Out:
#    Commodity Name     City Name  Type               Package       Variety  \
# 0        PUMPKINS  PHILADELPHIA   NaN          24 inch bins   HOWDEN TYPE
# 1        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 2        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 3        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 4        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 5        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 6        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 7        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 8        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 9        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 10       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 11       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 12       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 13       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 14       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 15       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 16       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 17       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 18       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 19       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 20       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 21       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 22       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 23       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 24       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 25       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 26       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 27       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 28       PUMPKINS  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE
# 29       PUMPKINS  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE
# 30       PUMPKINS  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE
# 31       PUMPKINS  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE
# 32       PUMPKINS  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE
# 33       PUMPKINS  PHILADELPHIA   NaN  1 1/9 bushel cartons      PIE TYPE
# 34       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 35       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 36       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 37       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 38       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 39       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 40       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 41       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 42       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 43       PUMPKINS  PHILADELPHIA   NaN          24 inch bins      PIE TYPE
# 44       PUMPKINS  PHILADELPHIA   NaN          24 inch bins  KNUCKLE HEAD
# 45       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 46       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 47       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 48       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 49       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 50       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 51       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 52       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 53       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 54       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 55       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
# 56       PUMPKINS  PHILADELPHIA   NaN    1/2 bushel cartons     MINIATURE
#
#    Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0          NaN    NaN  09/16/2017        140         150  ...    NaN
# 1          NaN    NaN  09/24/2016        150         150  ...    NaN
# 2          NaN    NaN  09/24/2016        150         150  ...    NaN
# 3          NaN    NaN  09/24/2016        150         160  ...    NaN
# 4          NaN    NaN  10/01/2016        140         140  ...    NaN
# 5          NaN    NaN  10/01/2016        140         140  ...    NaN
# 6          NaN    NaN  10/01/2016        120         120  ...    NaN
# 7          NaN    NaN  10/08/2016        140         155  ...    NaN
# 8          NaN    NaN  10/08/2016        120         120  ...    NaN
# 9          NaN    NaN  10/15/2016        120         125  ...    NaN
# 10         NaN    NaN  10/15/2016        100         125  ...    NaN
# 11         NaN    NaN  10/22/2016        130         140  ...    NaN
# 12         NaN    NaN  10/22/2016        120         120  ...    NaN
# 13         NaN    NaN  10/22/2016        130         140  ...    NaN
# 14         NaN    NaN  10/22/2016        100         120  ...    NaN
# 15         NaN    NaN  10/29/2016        130         140  ...    NaN
# 16         NaN    NaN  10/29/2016        120         120  ...    NaN
# 17         NaN    NaN  10/29/2016        130         140  ...    NaN
# 18         NaN    NaN  10/29/2016        100         120  ...    NaN
# 19         NaN    NaN  09/16/2017        120         120  ...    NaN
# 20         NaN    NaN  09/16/2017        120         150  ...    NaN
# 21         NaN    NaN  09/23/2017        140         140  ...    NaN
# 22         NaN    NaN  09/23/2017        150         150  ...    NaN
# 23         NaN    NaN  09/23/2017        120         150  ...    NaN
# 24         NaN    NaN  09/23/2017        140         150  ...    NaN
# 25         NaN    NaN  09/23/2017        140         150  ...    NaN
# 26         NaN    NaN  09/30/2017        140         140  ...    NaN
# 27         NaN    NaN  09/30/2017        140         140  ...    NaN
# 28         NaN    NaN  10/15/2016         12          14  ...    NaN
# 29         NaN    NaN  10/22/2016         12          12  ...    NaN
# 30         NaN    NaN  10/29/2016         12          12  ...    NaN
# 31         NaN    NaN  08/26/2017         18          20  ...    NaN
# 32         NaN    NaN  09/16/2017         18          18  ...    NaN
# 33         NaN    NaN  09/23/2017         18          22  ...    NaN
# 34         NaN    NaN  10/01/2016        250         250  ...    NaN
# 35         NaN    NaN  10/15/2016        140         140  ...    NaN
# 36         NaN    NaN  10/22/2016        140         150  ...    NaN
# 37         NaN    NaN  10/22/2016         75         100  ...    NaN
# 38         NaN    NaN  10/29/2016        140         150  ...    NaN
# 39         NaN    NaN  10/29/2016         75         100  ...    NaN
# 40         NaN    NaN  09/23/2017        180         180  ...    NaN
# 41         NaN    NaN  09/23/2017        140         140  ...    NaN
# 42         NaN    NaN  09/23/2017        180         180  ...    NaN
# 43         NaN    NaN  09/30/2017        140         140  ...    NaN
# 44         NaN    NaN  10/08/2016        210         210  ...    NaN
# 45   FLAT TYPE    NaN  09/24/2016         17          18  ...    NaN
# 46   FLAT TYPE    NaN  10/01/2016         18          18  ...    NaN
# 47   FLAT TYPE    NaN  10/01/2016         17          18  ...    NaN
# 48   FLAT TYPE    NaN  10/08/2016         15          15  ...    NaN
# 49   FLAT TYPE    NaN  10/15/2016         15          18  ...    NaN
# 50   FLAT TYPE    NaN  10/22/2016         16          18  ...    NaN
# 51   FLAT TYPE    NaN  10/29/2016         16          18  ...    NaN
# 52   FLAT TYPE    NaN  11/05/2016         16          18  ...    NaN
# 53   FLAT TYPE    NaN  08/26/2017         18          20  ...    NaN
# 54   FLAT TYPE    NaN  09/16/2017         16          16  ...    NaN
# 55   FLAT TYPE    NaN  09/23/2017         15          16  ...    NaN
# 56   FLAT TYPE    NaN  09/30/2017         15          18  ...    NaN
#
#     Environment Unit of Sale  Quality Condition  Appearance  Storage Crop  \
# 0           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 1           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 2           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 3           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 4           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 5           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 6           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 7           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 8           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 9           NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 10          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 11          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 12          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 13          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 14          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 15          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 16          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 17          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 18          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 19          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 20          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 21          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 22          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 23          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 24          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 25          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 26          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 27          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 28          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 29          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 30          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 31          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 32          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 33          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 34          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 35          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 36          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 37          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 38          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 39          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 40          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 41          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 42          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 43          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 44          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 45          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 46          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 47          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 48          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 49          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 50          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 51          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 52          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 53          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 54          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 55          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
# 56          NaN   SHELLACKED      NaN       NaN         NaN      NaN  NaN
#
#     Repack  Trans Mode
# 0        N         NaN
# 1        N         NaN
# 2        N         NaN
# 3        N         NaN
# 4        N         NaN
# 5        N         NaN
# 6        N         NaN
# 7        N         NaN
# 8        N         NaN
# 9        N         NaN
# 10       N         NaN
# 11       N         NaN
# 12       N         NaN
# 13       N         NaN
# 14       N         NaN
# 15       N         NaN
# 16       N         NaN
# 17       N         NaN
# 18       N         NaN
# 19       N         NaN
# 20       N         NaN
# 21       N         NaN
# 22       N         NaN
# 23       N         NaN
# 24       N         NaN
# 25       N         NaN
# 26       N         NaN
# 27       N         NaN
# 28       N         NaN
# 29       N         NaN
# 30       N         NaN
# 31       N         NaN
# 32       N         NaN
# 33       N         NaN
# 34       N         NaN
# 35       N         NaN
# 36       N         NaN
# 37       N         NaN
# 38       N         NaN
# 39       N         NaN
# 40       N         NaN
# 41       N         NaN
# 42       N         NaN
# 43       N         NaN
# 44       N         NaN
# 45       N         NaN
# 46       N         NaN
# 47       N         NaN
# 48       N         NaN
# 49       N         NaN
# 50       N         NaN
# 51       N         NaN
# 52       N         NaN
# 53       N         NaN
# 54       N         NaN
# 55       N         NaN
# 56       N         NaN
#
# [57 rows x 25 columns]

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data related to San Francisco. Pull up your notebook from the last lesson and use it as a reference to clean up these new dataframes.

# %%
# Clean your data here!

# %%
baltimore_modified_data = baltimore_data.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode", "Unit of Sale", "Color"], axis=1) 
baltimore_modified_data
# Out:
#     Commodity Name  City Name             Package      Variety Sub Variety  \
# 0         PUMPKINS  BALTIMORE        24 inch bins          NaN         NaN
# 1         PUMPKINS  BALTIMORE        24 inch bins          NaN         NaN
# 2         PUMPKINS  BALTIMORE        24 inch bins  HOWDEN TYPE         NaN
# 3         PUMPKINS  BALTIMORE        24 inch bins  HOWDEN TYPE         NaN
# 4         PUMPKINS  BALTIMORE        24 inch bins  HOWDEN TYPE         NaN
# ..             ...        ...                 ...          ...         ...
# 148       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE         NaN
# 149       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE         NaN
# 150       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  ROUND TYPE
# 151       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  ROUND TYPE
# 152       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  ROUND TYPE
#
#            Date  Low Price  High Price  Mostly Low  Mostly High        Origin  \
# 0    04/29/2017        270       280.0         270        280.0           NaN
# 1    05/06/2017        270       280.0         270        280.0           NaN
# 2    09/24/2016        160       160.0         160        160.0      DELAWARE
# 3    09/24/2016        160       160.0         160        160.0      VIRGINIA
# 4    11/05/2016         90       100.0          90        100.0      MARYLAND
# ..          ...        ...         ...         ...          ...           ...
# 148  09/30/2017         18        18.0          18         18.0      MARYLAND
# 149  09/30/2017         18        18.0          18         18.0  PENNSYLVANIA
# 150  09/24/2016         15        15.0          15         15.0      MARYLAND
# 151  10/01/2016         15        15.0          15         15.0      MARYLAND
# 152  10/08/2016         15        15.0          15         15.0      MARYLAND
#
#     Item Size Repack
# 0         lge      E
# 1         lge      E
# 2         med      N
# 3         med      N
# 4         lge      N
# ..        ...    ...
# 148       NaN      N
# 149       NaN      N
# 150       sml      N
# 151       sml      N
# 152       sml      N
#
# [153 rows x 13 columns]

# %%
boston_modified_data = boston_data.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode", "Unit of Sale", "Color"], axis=1) 
boston_modified_data
# Out:
#     Commodity Name City Name             Package      Variety Sub Variety  \
# 0         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE         NaN
# 1         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE         NaN
# 2         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE         NaN
# 3         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE         NaN
# 4         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE         NaN
# ..             ...       ...                 ...          ...         ...
# 347       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  ROUND TYPE
# 348       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  ROUND TYPE
# 349       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  ROUND TYPE
# 350       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  ROUND TYPE
# 351       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  ROUND TYPE
#
#            Date  Low Price  High Price  Mostly Low  Mostly High  \
# 0    09/24/2016        160         200         165          165
# 1    09/24/2016        160         200         165          165
# 2    09/24/2016        160         200         165          165
# 3    09/24/2016        160         200         165          165
# 4    09/24/2016        160         180         165          165
# ..          ...        ...         ...         ...          ...
# 347  10/22/2016         15          18          15           15
# 348  10/29/2016         15          18          15           15
# 349  10/29/2016         15          18          15           15
# 350  11/05/2016         15          18          15           15
# 351  11/05/2016         15          18          15           15
#
#             Origin Item Size Repack
# 0           CANADA     exjbo      N
# 1           CANADA       jbo      N
# 2           CANADA      xlge      N
# 3           CANADA      xlge      N
# 4           CANADA       lge      N
# ..             ...       ...    ...
# 347  MASSACHUSETTS       sml      N
# 348  MASSACHUSETTS       sml      N
# 349  MASSACHUSETTS       sml      N
# 350  MASSACHUSETTS       sml      N
# 351  MASSACHUSETTS       sml      N
#
# [352 rows x 13 columns]

# %%
newyork_modified_data = newyork_data.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode", "Unit of Sale", "Color"], axis=1) 
newyork_modified_data
# Out:
#     Commodity Name City Name              Package      Variety Sub Variety  \
# 0         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE         NaN
# 1         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE         NaN
# 2         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE         NaN
# 3         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE         NaN
# 4         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE         NaN
# ..             ...       ...                  ...          ...         ...
# 107       PUMPKINS  NEW YORK       bushel cartons    MINIATURE         NaN
# 108       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
# 109       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
# 110       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
# 111       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  ROUND TYPE
#
#            Date  Low Price  High Price  Mostly Low  Mostly High      Origin  \
# 0    09/24/2016        150         170         150          170    MICHIGAN
# 1    09/24/2016        150         170         150          170    MICHIGAN
# 2    09/24/2016        130         150         130          150  NEW JERSEY
# 3    09/24/2016        130         150         130          150  NEW JERSEY
# 4    09/24/2016        120         140         120          140    NEW YORK
# ..          ...        ...         ...         ...          ...         ...
# 107  09/09/2017         32          32          32           32        OHIO
# 108  10/08/2016         18          18          18           18    NEW YORK
# 109  10/08/2016         18          18          18           18    NEW YORK
# 110  10/15/2016         18          18          18           18    NEW YORK
# 111  10/15/2016         18          18          18           18    NEW YORK
#
#     Item Size Repack
# 0        xlge      N
# 1         lge      N
# 2        xlge      N
# 3         lge      N
# 4     med-lge      N
# ..        ...    ...
# 107       sml      N
# 108       med      N
# 109       sml      N
# 110       med      N
# 111       sml      N
#
# [112 rows x 13 columns]

# %%
philadelphia_modified_data = philadelphia_data.drop(["Type", "Grade", "Origin District", "Environment", "Quality", "Condition", "Appearance", "Storage", "Crop", "Trans Mode", "Unit of Sale", "Color"], axis=1) 
philadelphia_modified_data
# Out:
#    Commodity Name     City Name               Package       Variety  \
# 0        PUMPKINS  PHILADELPHIA          24 inch bins   HOWDEN TYPE
# 1        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 2        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 3        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 4        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 5        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 6        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 7        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 8        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 9        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 10       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 11       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 12       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 13       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 14       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 15       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 16       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 17       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 18       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 19       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 20       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 21       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 22       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 23       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 24       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 25       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 26       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 27       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 28       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 29       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 30       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 31       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 32       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 33       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 34       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 35       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 36       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 37       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 38       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 39       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 40       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 41       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 42       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 43       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 44       PUMPKINS  PHILADELPHIA          24 inch bins  KNUCKLE HEAD
# 45       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 46       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 47       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 48       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 49       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 50       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 51       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 52       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 53       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 54       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 55       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 56       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
#
#    Sub Variety        Date  Low Price  High Price  Mostly Low  Mostly High  \
# 0          NaN  09/16/2017        140         150         140          150
# 1          NaN  09/24/2016        150         150         150          150
# 2          NaN  09/24/2016        150         150         150          150
# 3          NaN  09/24/2016        150         160         150          160
# 4          NaN  10/01/2016        140         140         140          140
# 5          NaN  10/01/2016        140         140         140          140
# 6          NaN  10/01/2016        120         120         120          120
# 7          NaN  10/08/2016        140         155         140          155
# 8          NaN  10/08/2016        120         120         120          120
# 9          NaN  10/15/2016        120         125         120          125
# 10         NaN  10/15/2016        100         125         100          125
# 11         NaN  10/22/2016        130         140         130          140
# 12         NaN  10/22/2016        120         120         120          120
# 13         NaN  10/22/2016        130         140         130          140
# 14         NaN  10/22/2016        100         120         100          120
# 15         NaN  10/29/2016        130         140         130          140
# 16         NaN  10/29/2016        120         120         120          120
# 17         NaN  10/29/2016        130         140         130          140
# 18         NaN  10/29/2016        100         120         120          120
# 19         NaN  09/16/2017        120         120         120          120
# 20         NaN  09/16/2017        120         150         120          150
# 21         NaN  09/23/2017        140         140         140          140
# 22         NaN  09/23/2017        150         150         150          150
# 23         NaN  09/23/2017        120         150         120          150
# 24         NaN  09/23/2017        140         150         140          150
# 25         NaN  09/23/2017        140         150         140          150
# 26         NaN  09/30/2017        140         140         140          140
# 27         NaN  09/30/2017        140         140         140          140
# 28         NaN  10/15/2016         12          14          12           14
# 29         NaN  10/22/2016         12          12          12           12
# 30         NaN  10/29/2016         12          12          12           12
# 31         NaN  08/26/2017         18          20          18           20
# 32         NaN  09/16/2017         18          18          18           18
# 33         NaN  09/23/2017         18          22          18           22
# 34         NaN  10/01/2016        250         250         250          250
# 35         NaN  10/15/2016        140         140         140          140
# 36         NaN  10/22/2016        140         150         140          150
# 37         NaN  10/22/2016         75         100          75          100
# 38         NaN  10/29/2016        140         150         140          150
# 39         NaN  10/29/2016         75         100          75          100
# 40         NaN  09/23/2017        180         180         180          180
# 41         NaN  09/23/2017        140         140         140          140
# 42         NaN  09/23/2017        180         180         180          180
# 43         NaN  09/30/2017        140         140         140          140
# 44         NaN  10/08/2016        210         210         210          210
# 45   FLAT TYPE  09/24/2016         17          18          17           18
# 46   FLAT TYPE  10/01/2016         18          18          18           18
# 47   FLAT TYPE  10/01/2016         17          18          17           18
# 48   FLAT TYPE  10/08/2016         15          15          15           15
# 49   FLAT TYPE  10/15/2016         15          18          15           18
# 50   FLAT TYPE  10/22/2016         16          18          16           18
# 51   FLAT TYPE  10/29/2016         16          18          16           18
# 52   FLAT TYPE  11/05/2016         16          18          16           18
# 53   FLAT TYPE  08/26/2017         18          20          18           20
# 54   FLAT TYPE  09/16/2017         16          16          16           16
# 55   FLAT TYPE  09/23/2017         15          16          15           16
# 56   FLAT TYPE  09/30/2017         15          18          15           18
#
#           Origin Item Size Repack
# 0   PENNSYLVANIA       lge      N
# 1       NEW YORK   med-lge      N
# 2       NEW YORK       med      N
# 3   PENNSYLVANIA       lge      N
# 4     NEW JERSEY   med-lge      N
# 5   PENNSYLVANIA   med-lge      N
# 6   PENNSYLVANIA       med      N
# 7     NEW JERSEY       med      N
# 8     NEW JERSEY       sml      N
# 9   PENNSYLVANIA       lge      N
# 10  PENNSYLVANIA       med      N
# 11    NEW JERSEY   med-lge      N
# 12  PENNSYLVANIA       lge      N
# 13  PENNSYLVANIA   med-lge      N
# 14  PENNSYLVANIA       med      N
# 15    NEW JERSEY   med-lge      N
# 16  PENNSYLVANIA       lge      N
# 17  PENNSYLVANIA   med-lge      N
# 18  PENNSYLVANIA       med      N
# 19  PENNSYLVANIA       lge      N
# 20  PENNSYLVANIA       med      N
# 21      DELAWARE       lge      N
# 22      DELAWARE       med      N
# 23      NEW YORK       lge      N
# 24  PENNSYLVANIA      xlge      N
# 25  PENNSYLVANIA       lge      N
# 26      DELAWARE       lge      N
# 27      DELAWARE       med      N
# 28          OHIO       med      N
# 29          OHIO       med      N
# 30          OHIO       med      N
# 31      MICHIGAN       med      N
# 32          OHIO       med      N
# 33          OHIO       med      N
# 34  PENNSYLVANIA       med      N
# 35  PENNSYLVANIA       med      N
# 36  PENNSYLVANIA       med      N
# 37  PENNSYLVANIA       sml      N
# 38  PENNSYLVANIA       med      N
# 39  PENNSYLVANIA       sml      N
# 40      DELAWARE       med      N
# 41      DELAWARE       sml      N
# 42      NEW YORK       med      N
# 43      DELAWARE       sml      N
# 44    NEW JERSEY       med      N
# 45          OHIO       NaN      N
# 46    NEW JERSEY       NaN      N
# 47          OHIO       NaN      N
# 48          OHIO       NaN      N
# 49          OHIO       NaN      N
# 50          OHIO       NaN      N
# 51          OHIO       NaN      N
# 52          OHIO       NaN      N
# 53      MICHIGAN       NaN      N
# 54          OHIO       NaN      N
# 55          OHIO       NaN      N
# 56          OHIO       NaN      N

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!

combined_df = pd.concat([baltimore_modified_data, boston_modified_data, newyork_modified_data, philadelphia_modified_data], axis=0, ignore_index=True)
combined_df
# Out:
#     Commodity Name     City Name             Package      Variety Sub Variety  \
# 0         PUMPKINS     BALTIMORE        24 inch bins          NaN         NaN
# 1         PUMPKINS     BALTIMORE        24 inch bins          NaN         NaN
# 2         PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE         NaN
# 3         PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE         NaN
# 4         PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE         NaN
# ..             ...           ...                 ...          ...         ...
# 669       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE   FLAT TYPE
# 670       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE   FLAT TYPE
# 671       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE   FLAT TYPE
# 672       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE   FLAT TYPE
# 673       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE   FLAT TYPE
#
#            Date  Low Price  High Price  Mostly Low  Mostly High    Origin  \
# 0    04/29/2017        270       280.0         270        280.0       NaN
# 1    05/06/2017        270       280.0         270        280.0       NaN
# 2    09/24/2016        160       160.0         160        160.0  DELAWARE
# 3    09/24/2016        160       160.0         160        160.0  VIRGINIA
# 4    11/05/2016         90       100.0          90        100.0  MARYLAND
# ..          ...        ...         ...         ...          ...       ...
# 669  11/05/2016         16        18.0          16         18.0      OHIO
# 670  08/26/2017         18        20.0          18         20.0  MICHIGAN
# 671  09/16/2017         16        16.0          16         16.0      OHIO
# 672  09/23/2017         15        16.0          15         16.0      OHIO
# 673  09/30/2017         15        18.0          15         18.0      OHIO
#
#     Item Size Repack
# 0         lge      E
# 1         lge      E
# 2         med      N
# 3         med      N
# 4         lge      N
# ..        ...    ...
# 669       NaN      N
# 670       NaN      N
# 671       NaN      N
# 672       NaN      N
# 673       NaN      N
#
# [674 rows x 13 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of **unit of sale** in the Northeast region?
# 2. For each region, what is the average number of pumpkins per variety that came into terminal markets for the year?

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
# combined_df.describe()
# Out:
#         Low Price  High Price  Mostly Low  Mostly High
# count  674.000000  674.000000  674.000000   674.000000
# mean   134.183976  150.671365  139.405045   144.815282
# std     85.808134   95.330690   90.648517    92.452058
# min     12.000000   12.000000   12.000000    12.000000
# 25%     24.000000   24.000000   24.000000    24.000000
# 50%    150.000000  170.000000  150.000000   160.000000
# 75%    180.000000  225.000000  200.000000   200.000000
# max    380.000000  380.000000  380.000000   380.000000

# %%
dictionary_df_aggregate = {
    "Low Price": ["mean"],
    "High Price": ["mean"]
}

dictionary_aggregate = combined_df.agg(dictionary_df_aggregate)
dictionary_aggregate
# Out:
#        Low Price  High Price
# mean  134.183976  150.671365

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
combined_df['Variety'].value_counts()
# Out:
# Variety
# HOWDEN TYPE                 224
# PIE TYPE                    198
# MINIATURE                    97
# BIG MACK TYPE                55
# CINDERELLA                   39
# FAIRYTALE                    37
# KNUCKLE HEAD                  9
# BLUE TYPE                     7
# MIXED HEIRLOOM VARIETIES      4
# HOWDEN WHITE TYPE             2
# Name: count, dtype: int64

# %%
grouping_df = combined_df.groupby(["Variety"]).count()
grouping_df
# Out:
#                           Commodity Name  City Name  Package  Sub Variety  \
# Variety
# BIG MACK TYPE                         55         55       55            0
# BLUE TYPE                              7          7        7            0
# CINDERELLA                            39         39       39            0
# FAIRYTALE                             37         37       37            0
# HOWDEN TYPE                          224        224      224            0
# HOWDEN WHITE TYPE                      2          2        2            0
# KNUCKLE HEAD                           9          9        9            0
# MINIATURE                             97         97       97           83
# MIXED HEIRLOOM VARIETIES               4          4        4            0
# PIE TYPE                             198        198      198            0
#
#                           Date  Low Price  High Price  Mostly Low  \
# Variety
# BIG MACK TYPE               55         55          55          55
# BLUE TYPE                    7          7           7           7
# CINDERELLA                  39         39          39          39
# FAIRYTALE                   37         37          37          37
# HOWDEN TYPE                224        224         224         224
# HOWDEN WHITE TYPE            2          2           2           2
# KNUCKLE HEAD                 9          9           9           9
# MINIATURE                   97         97          97          97
# MIXED HEIRLOOM VARIETIES     4          4           4           4
# PIE TYPE                   198        198         198         198
#
#                           Mostly High  Origin  Item Size  Repack
# Variety
# BIG MACK TYPE                      55      55         45      55
# BLUE TYPE                           7       7          7       7
# CINDERELLA                         39      36         39      39
# FAIRYTALE                          37      37         37      37
# HOWDEN TYPE                       224     224        224     224
# HOWDEN WHITE TYPE                   2       2          2       2
# KNUCKLE HEAD                        9       9          9       9
# MINIATURE                          97      97         80      97
# MIXED HEIRLOOM VARIETIES            4       4          0       4
# PIE TYPE                          198     198        180     198

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
